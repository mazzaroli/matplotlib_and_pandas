# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Pyplot Basico
# [Documentación para graficar](https://matplotlib.org/stable/plot_types/basic/stem.html)

# %%
x = np.linspace(0,5,11)
y = x**2

# %% [markdown]
# ## Plot

# %%
plt.plot(x,'bo',)

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,'r')
plt.show()

# %%
plt.plot(x,y,'yo')
plt.show()

# %%
plt.plot(x,y,'gx')
plt.show()

# %%
plt.plot(x,y,'rs-')
plt.show()

# %%
plt.plot(x,y,'yD:')
plt.show()

# %% [markdown]
# ## Histograma

# %%
plt.hist(x)
plt.show()

# %% [markdown]
# ## Grafica de Torta

# %%
plt.pie(x)
plt.show()

# %% [markdown]
# ## Grafica de Dispersión

# %%
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ## Diagrama de caja

# %%
plt.boxplot(x)
plt.show()

# %% [markdown]
# ## Pruebas de distintos graficos

# %% [markdown]
# stem

# %%
plt.stem(x,y,'r','sg-')
plt.show()

# %% [markdown]
# Histograma 2

# %%
plt.hist2d(x,y)
plt.show()

# %%
plt.hist(x,y)
plt.show()

# %% [markdown]
# Tricountour

# %%
plt.plot(x,'bo')

# %%
x = np.random.randint(10,20,40)
y = np.random.randint(10,20,40)
z = np.random.randint(10,20,40)
plt.tricontourf(x,y,z)
plt.show()
