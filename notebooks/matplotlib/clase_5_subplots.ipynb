# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,5,100)
y = np.sin(x)

# %% [markdown]
# # Subplots

# %%
fig, axes = plt.subplots()

axes.plot(x,y,'b')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

axes[0].plot(x,y,'b')
axes[1].plot(y,x,'r')

# %%
    


fig, axes = plt.subplots(nrows=2, ncols=4)

axes[0,0].plot(x,np.cos(x),'blue')
axes[0,1].plot(x,np.sin(x),'green')
axes[0,2].plot(x,np.tan(x),'turquoise')
axes[0,3].plot(x,np.cos(x),'gold')

# %%
fig, ((ax1,ax2,ax3,ax4),(ax5,ax6,ax7,ax8)) = plt.subplots(nrows=2, ncols=4)

ax1.plot(x,np.cos(x),'blue')
ax2.plot(x,np.sin(x),'green')
ax3.plot(x,np.tan(x),'turquoise')
ax4.plot(x,np.cos(x),'gold')
fig.tight_layout()

# %% [markdown]
# ## Reto
# Graficar lo que queramos en la segunda linea

# %%
def fibbo(): 
    # El siguiente dibujo toma n = 7 como ejemplo
    count = 7
    f_list = fibo(count)
    x0_array,y0_array = find_o_xy(f_list)

    #La longitud del lado correspondiente a cada cuadrado, como se muestra en el ejemplo, el radio comienza desde 1, 2 ...
    f_list_r = fibo(count+2)[2::]

    # Dibuja el 1/4 de círculo en cada cuadrado
    start_angle, end_angle = np.pi, 1.5*np.pi
    for n in np.arange(len(f_list)):
        t=np.arange(start_angle,end_angle,0.001)
        circle_x = (f_list_r[n])*(np.sin(t))+x0_array[n]
        circle_y = (f_list_r[n])*(np.cos(t))+y0_array[n]
        
        start_angle += 0.5*np.pi
        end_angle += 0.5*np.pi
        
        plt.plot(circle_x,circle_y,color='red')



fig, ((ax1,ax2,ax3,ax4),(ax5,ax6,ax7,ax8)) = plt.subplots(nrows=2, ncols=4)

ax1.plot(x,np.cos(x),'blue')
ax2.plot(x,np.sin(x),'green')
ax3.plot(x,np.tan(x),'turquoise')
ax4.plot(x,np.cos(x),'gold')

ax5.plot(y,y**2,'blue')
ax6.plot(y,y**3,'green')
ax7.plot(y,y**4,'turquoise')
ax8 = fibbo()

fig.tight_layout()
