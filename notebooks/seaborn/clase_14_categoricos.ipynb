# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Graficos Categóricos

# %%
tips = sns.load_dataset('tips')
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %% [markdown]
# ## Countplot

# %%
sns.countplot(data=tips, x='day', hue='sex');

# %% [markdown]
# ## Stripplot

# %%
plt.figure(figsize=(10,6))
sns.stripplot(data=tips,x='day' , y='total_bill', hue='sex', dodge=True);

# %% [markdown]
# ## Swarmplot

# %%
plt.figure(figsize=(6,6))
sns.swarmplot(data=tips,x='day' , y='total_bill', hue='sex', dodge=True)
plt.show()

# %% [markdown]
# ## Boxplot
# Se puede graficar tanto variables categoricas(imagen 1) como numericas(imagen 2)

# %%
plt.figure(figsize=(6,6))
sns.boxplot(data=tips,x='day' , y='total_bill', hue='sex', dodge=True)
sns.swarmplot(data=tips,x='day' , y='total_bill', hue='sex', dodge=True, color='0', marker='<')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.boxplot(data=tips, y='total_bill')
plt.show()

# %% [markdown]
# ## Violinplot
# Al igual que el boxplot, podemos graficar variables categoricas(imagen 1 y 2) o numericas(imagen 3)

# %%
plt.figure(figsize=(6,6))
sns.violinplot(data=tips,x='day' , y='total_bill', hue='sex' ,palette='pastel')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.violinplot(data=tips,x='day' , y='total_bill', hue='sex', split=True,palette='pastel')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.violinplot(data=tips,y='total_bill')
plt.show()

# %% [markdown]
# ## Catplot
# Similar a ```displot```, pero sirve para graficar graficos categoricos

# %%
sns.catplot(data=tips,x='day' , y='total_bill', hue='sex')
plt.show()

# %% [markdown]
# ## Catplot
# Similar a ```displot```, pero sirve para graficar graficos categoricos

# %%
sns.catplot(data=tips,x='day' , y='total_bill', hue='sex', dodge=True)
plt.show()

# %%
sns.catplot(data=tips,x='day' , y='total_bill', hue='sex', dodge=True, kind='swarm')
plt.show()
# Out:
# /home/mazzaroli/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 6.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(data=tips,x='day' , y='total_bill', hue='sex', dodge=True, kind='box')
plt.show()

# %%
sns.catplot(data=tips,x='day' , y='total_bill', hue='sex', dodge=True, kind='boxen', col='time', orient='v')
plt.show()

# %% [markdown]
# ## Pruebas Locas

# %%
result = tips.groupby('sex').agg(['mean','max','min'])
result
# Out:
#        total_bill                    tip                 size
#              mean    max   min      mean   max  min      mean max min
# sex
# Male    20.744076  50.81  7.25  3.089618  10.0  1.0  2.630573   6   1
# Female  18.056897  44.30  3.07  2.833448   6.5  1.0  2.459770   6   1

# %%
result[['total_bill','tip']]
# Out:
#        total_bill                    tip
#              mean    max   min      mean   max  min
# sex
# Male    20.744076  50.81  7.25  3.089618  10.0  1.0
# Female  18.056897  44.30  3.07  2.833448   6.5  1.0

# %%
sns.catplot(data=tips, x="day", hue="size", col="time", kind= "count" )
plt.show()
